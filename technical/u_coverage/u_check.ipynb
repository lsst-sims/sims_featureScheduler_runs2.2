# %%
import rubin_sim
from rubin_sim import maf
import matplotlib.pylab as plt
# %matplotlib inline
import healpy as hp
import numpy as np
import glob

# %%
files = glob.glob('*10yrs.db')
files.sort()

# %%
files
# Out:
# ['baseline_v2.1_10yrs.db',
#  'baseline_v2.2_10yrs.db',
#  'u_coverage_templatew0_v2.2_10yrs.db',
#  'u_coverage_templatew100_v2.2_10yrs.db',
#  'u_coverage_templatew12_v2.2_10yrs.db',
#  'u_coverage_templatew200_v2.2_10yrs.db',
#  'u_coverage_templatew24_v2.2_10yrs.db',
#  'u_coverage_templatew3_v2.2_10yrs.db',
#  'u_coverage_templatew500_v2.2_10yrs.db',
#  'u_coverage_templatew50_v2.2_10yrs.db',
#  'u_coverage_templatew6_v2.2_10yrs.db',
#  'u_coverage_u_templatew0_v2.2_10yrs.db',
#  'u_coverage_u_templatew100_v2.2_10yrs.db',
#  'u_coverage_u_templatew12_v2.2_10yrs.db',
#  'u_coverage_u_templatew200_v2.2_10yrs.db',
#  'u_coverage_u_templatew24_v2.2_10yrs.db',
#  'u_coverage_u_templatew3_v2.2_10yrs.db',
#  'u_coverage_u_templatew500_v2.2_10yrs.db',
#  'u_coverage_u_templatew50_v2.2_10yrs.db',
#  'u_coverage_u_templatew6_v2.2_10yrs.db']

# %%
areas = []
for filename in files:
    runname = filename.split('/')[-1].replace('.db', '')
    slicer = maf.HealpixSlicer()
    # just count how many observations overlap the point
    metric = maf.CountMetric(col='night')
    # limit the data to just things on one night
    sql='filter="u" and night < 365 and note not like "%%DD%%"'
    summarystats = [maf.AreaThresholdMetric(lower_threshold=3)]
    
    bundle = maf.MetricBundle(metric, slicer, sql, runName=runname,
                             summaryMetrics=summarystats)
    bg = maf.MetricBundleGroup([bundle], filename, '.', None)
    bg.runAll()
    bg.plotAll(closefigs=False)
    
    areas.append(bundle.summaryValues)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 13086 visits
# Running:  ['baseline_v2_1_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# 0.0 180.0 -180.0 180.0
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 3066 visits
# Running:  ['baseline_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# 0.0 180.0 -180.0 180.0
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/metricBundles/metricBundleGroup.py:291: UserWarning: No data matching constraint filter="u" and night < 365 and note not like "%%DD%%"
#   warnings.warn("No data matching constraint %s" % constraint)
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/metricBundles/metricBundleGroup.py:298: UserWarning:  This means skipping metrics ['Count night : u and night < 365 and note not like %%DD%% : HealpixSlicer']
#   warnings.warn(" This means skipping metrics %s" % metricsSkipped)
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/plots/plotHandler.py:608: UserWarning: MetricBundle (u_coverage_templatew0_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL) has no attribute "metricValues". Either the values have not been calculated or they have been deleted.
#   warnings.warn(msg)
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 14445 visits
# Running:  ['u_coverage_templatew100_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# 0.0 180.0 -180.0 180.0
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 3066 visits
# Running:  ['u_coverage_templatew12_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# 0.0 180.0 -180.0 180.0
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 15581 visits
# Running:  ['u_coverage_templatew200_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# 0.0 180.0 -180.0 180.0
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 9336 visits
# Running:  ['u_coverage_templatew24_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# 0.0 180.0 -180.0 180.0
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/metricBundles/metricBundleGroup.py:291: UserWarning: No data matching constraint filter="u" and night < 365 and note not like "%%DD%%"
#   warnings.warn("No data matching constraint %s" % constraint)
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/metricBundles/metricBundleGroup.py:298: UserWarning:  This means skipping metrics ['Count night : u and night < 365 and note not like %%DD%% : HealpixSlicer']
#   warnings.warn(" This means skipping metrics %s" % metricsSkipped)
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/plots/plotHandler.py:608: UserWarning: MetricBundle (u_coverage_templatew3_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL) has no attribute "metricValues". Either the values have not been calculated or they have been deleted.
#   warnings.warn(msg)
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 15939 visits
# Running:  ['u_coverage_templatew500_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# 0.0 180.0 -180.0 180.0
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 12804 visits
# Running:  ['u_coverage_templatew50_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# 0.0 180.0 -180.0 180.0
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 200 visits
# Running:  ['u_coverage_templatew6_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# 0.0 180.0 -180.0 180.0
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/utils/mafUtils.py:141: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn(
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/metricBundles/metricBundleGroup.py:291: UserWarning: No data matching constraint filter="u" and night < 365 and note not like "%%DD%%"
#   warnings.warn("No data matching constraint %s" % constraint)
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/metricBundles/metricBundleGroup.py:298: UserWarning:  This means skipping metrics ['Count night : u and night < 365 and note not like %%DD%% : HealpixSlicer']
#   warnings.warn(" This means skipping metrics %s" % metricsSkipped)
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/plots/plotHandler.py:608: UserWarning: MetricBundle (u_coverage_u_templatew0_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL) has no attribute "metricValues". Either the values have not been calculated or they have been deleted.
#   warnings.warn(msg)
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 14062 visits
# Running:  ['u_coverage_u_templatew100_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# 0.0 180.0 -180.0 180.0
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 3066 visits
# Running:  ['u_coverage_u_templatew12_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# 0.0 180.0 -180.0 180.0
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 15148 visits
# Running:  ['u_coverage_u_templatew200_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# 0.0 180.0 -180.0 180.0
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 10497 visits
# Running:  ['u_coverage_u_templatew24_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# 0.0 180.0 -180.0 180.0
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 100 visits
# Running:  ['u_coverage_u_templatew3_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# 0.0 180.0 -180.0 180.0
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/utils/mafUtils.py:141: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn(
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 17773 visits
# Running:  ['u_coverage_u_templatew500_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# 0.0 180.0 -180.0 180.0
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 13565 visits
# Running:  ['u_coverage_u_templatew50_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# 0.0 180.0 -180.0 180.0
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# Plotting complete.
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying table None with constraint filter="u" and night < 365 and note not like "%%DD%%" for columns ['night', 'fieldDec', 'fieldRA', 'rotSkyPos']
# Found 250 visits
# Running:  ['u_coverage_u_templatew6_v2_2_10yrs_Count_night_u_and_night_lt_365_and_note_not_like_DD_HEAL']
# 0.0 180.0 -180.0 180.0
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="u" and night < 365 and note not like "%%DD%%"" constraint now.
# Plotting complete.

# %%
for a,n in zip(areas, files):
    if a is None:
        print(n, None)
    else:
        print(n,a['AreaThreshold'])
# Out:
# baseline_v2.1_10yrs.db 19016.505589783315
# baseline_v2.2_10yrs.db 1343.918949394381
# u_coverage_templatew0_v2.2_10yrs.db None
# u_coverage_templatew100_v2.2_10yrs.db 19406.777134806507
# u_coverage_templatew12_v2.2_10yrs.db 1343.918949394381
# u_coverage_templatew200_v2.2_10yrs.db 20668.8649537928
# u_coverage_templatew24_v2.2_10yrs.db 11510.70252065985
# u_coverage_templatew3_v2.2_10yrs.db None
# u_coverage_templatew500_v2.2_10yrs.db 21127.958577723308
# u_coverage_templatew50_v2.2_10yrs.db 18987.75978243483
# u_coverage_templatew6_v2.2_10yrs.db 0.0
# u_coverage_u_templatew0_v2.2_10yrs.db None
# u_coverage_u_templatew100_v2.2_10yrs.db 18896.066951695513
# u_coverage_u_templatew12_v2.2_10yrs.db 1343.918949394381
# u_coverage_u_templatew200_v2.2_10yrs.db 19921.473962732256
# u_coverage_u_templatew24_v2.2_10yrs.db 14591.120021996134
# u_coverage_u_templatew3_v2.2_10yrs.db 0.0
# u_coverage_u_templatew500_v2.2_10yrs.db 22028.310835623586
# u_coverage_u_templatew50_v2.2_10yrs.db 19398.174374943093
# u_coverage_u_templatew6_v2.2_10yrs.db 11.330464210350751
