# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import pandas as pd

# %%
data = pd.read_hdf('summary.h5')

# %%
data
# Out:
#                                           20thPercentile Inter-Night Gap All sky all bands Count  \
# baseline_v2.2_10yrs                                                                 33538.0
# carina_v2.2_10yrs                                                                   33538.0
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                             33534.0
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                             33539.0
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                            33546.0
# ...                                                                                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                                                    34644.0
# twi_neo_repeat4_z_np4_v2.2_10yrs                                                    34449.0
# twi_neo_repeat4_z_np5_v2.2_10yrs                                                    34698.0
# twi_neo_repeat4_z_np6_v2.2_10yrs                                                    34671.0
# twi_neo_repeat4_z_np7_v2.2_10yrs                                                    34613.0
#
#                                           20thPercentile Inter-Night Gap All sky all bands Max  \
# baseline_v2.2_10yrs                                                             2984.793897
# carina_v2.2_10yrs                                                               3258.020258
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                         3258.144473
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                         3258.137598
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                        2894.957763
# ...                                                                                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                                                3351.816084
# twi_neo_repeat4_z_np4_v2.2_10yrs                                                2899.052012
# twi_neo_repeat4_z_np5_v2.2_10yrs                                                2971.846871
# twi_neo_repeat4_z_np6_v2.2_10yrs                                                2932.938494
# twi_neo_repeat4_z_np7_v2.2_10yrs                                                3351.813335
#
#                                           20thPercentile Inter-Night Gap All sky all bands Mean  \
# baseline_v2.2_10yrs                                                                4.461813
# carina_v2.2_10yrs                                                                  4.417602
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                            4.368272
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                            3.746747
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                           4.143389
# ...                                                                                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                                                  13.928533
# twi_neo_repeat4_z_np4_v2.2_10yrs                                                  16.051569
# twi_neo_repeat4_z_np5_v2.2_10yrs                                                   7.471037
# twi_neo_repeat4_z_np6_v2.2_10yrs                                                  10.092419
# twi_neo_repeat4_z_np7_v2.2_10yrs                                                  12.907555
#
#                                           20thPercentile Inter-Night Gap All sky all bands Median  \
# baseline_v2.2_10yrs                                                                1.027080
# carina_v2.2_10yrs                                                                  1.026867
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                            1.023364
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                            0.996664
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                           1.028946
# ...                                                                                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                                                   1.030778
# twi_neo_repeat4_z_np4_v2.2_10yrs                                                   1.032131
# twi_neo_repeat4_z_np5_v2.2_10yrs                                                   1.023850
# twi_neo_repeat4_z_np6_v2.2_10yrs                                                   1.026866
# twi_neo_repeat4_z_np7_v2.2_10yrs                                                   1.026137
#
#                                           20thPercentile Inter-Night Gap All sky all bands Min  \
# baseline_v2.2_10yrs                                                                0.948068
# carina_v2.2_10yrs                                                                  0.656967
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                            0.949107
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                            0.932083
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                           0.945698
# ...                                                                                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                                                   0.948581
# twi_neo_repeat4_z_np4_v2.2_10yrs                                                   0.942007
# twi_neo_repeat4_z_np5_v2.2_10yrs                                                   0.947335
# twi_neo_repeat4_z_np6_v2.2_10yrs                                                   0.952818
# twi_neo_repeat4_z_np7_v2.2_10yrs                                                   0.947123
#
#                                           20thPercentile Inter-Night Gap All sky all bands N(+3Sigma)  \
# baseline_v2.2_10yrs                                                                   107.0
# carina_v2.2_10yrs                                                                     126.0
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                               123.0
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                               111.0
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                              103.0
# ...                                                                                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                                                      462.0
# twi_neo_repeat4_z_np4_v2.2_10yrs                                                      583.0
# twi_neo_repeat4_z_np5_v2.2_10yrs                                                      238.0
# twi_neo_repeat4_z_np6_v2.2_10yrs                                                      318.0
# twi_neo_repeat4_z_np7_v2.2_10yrs                                                      416.0
#
#                                           20thPercentile Inter-Night Gap All sky all bands N(-3Sigma)  \
# baseline_v2.2_10yrs                                                                     0.0
# carina_v2.2_10yrs                                                                       0.0
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                                 0.0
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                                 0.0
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                                0.0
# ...                                                                                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                                                        0.0
# twi_neo_repeat4_z_np4_v2.2_10yrs                                                        0.0
# twi_neo_repeat4_z_np5_v2.2_10yrs                                                        0.0
# twi_neo_repeat4_z_np6_v2.2_10yrs                                                        0.0
# twi_neo_repeat4_z_np7_v2.2_10yrs                                                        0.0
#
#                                           20thPercentile Inter-Night Gap All sky all bands Rms  \
# baseline_v2.2_10yrs                                                               55.727320
# carina_v2.2_10yrs                                                                 56.281131
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                           56.332976
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                           46.016632
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                          52.972064
# ...                                                                                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                                                 112.541902
# twi_neo_repeat4_z_np4_v2.2_10yrs                                                 112.087971
# twi_neo_repeat4_z_np5_v2.2_10yrs                                                  81.264202
# twi_neo_repeat4_z_np6_v2.2_10yrs                                                  94.620878
# twi_neo_repeat4_z_np7_v2.2_10yrs                                                 106.104020
#
#                                           20thPercentile Inter-Night Gap All sky g band Count  \
# baseline_v2.2_10yrs                                                                 33394.0
# carina_v2.2_10yrs                                                                   33412.0
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                             33397.0
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                             33408.0
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                            33422.0
# ...                                                                                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                                                    33402.0
# twi_neo_repeat4_z_np4_v2.2_10yrs                                                    33417.0
# twi_neo_repeat4_z_np5_v2.2_10yrs                                                    33401.0
# twi_neo_repeat4_z_np6_v2.2_10yrs                                                    33419.0
# twi_neo_repeat4_z_np7_v2.2_10yrs                                                    33422.0
#
#                                           20thPercentile Inter-Night Gap All sky g band Max  \
# baseline_v2.2_10yrs                                                             3212.219410
# carina_v2.2_10yrs                                                               3293.981775
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                         3271.013189
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                         3206.218176
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                        3333.908124
# ...                                                                                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                                                2892.115819
# twi_neo_repeat4_z_np4_v2.2_10yrs                                                3199.167455
# twi_neo_repeat4_z_np5_v2.2_10yrs                                                3331.891896
# twi_neo_repeat4_z_np6_v2.2_10yrs                                                3548.208632
# twi_neo_repeat4_z_np7_v2.2_10yrs                                                3227.201852
#
#                                           ...  properMotion  90th%ile  \
# baseline_v2.2_10yrs                       ...                0.326443
# carina_v2.2_10yrs                         ...                0.326181
# clouds_baseline_cloudso0_ns2_v2.2_10yrs   ...                0.324830
# clouds_baseline_cloudso0_ns3_v2.2_10yrs   ...                0.319873
# clouds_baseline_cloudso10_ns2_v2.2_10yrs  ...                0.324007
# ...                                       ...                     ...
# twi_neo_repeat4_z_np3_v2.2_10yrs          ...                0.362589
# twi_neo_repeat4_z_np4_v2.2_10yrs          ...                0.355572
# twi_neo_repeat4_z_np5_v2.2_10yrs          ...                0.366712
# twi_neo_repeat4_z_np6_v2.2_10yrs          ...                0.363163
# twi_neo_repeat4_z_np7_v2.2_10yrs          ...                0.361405
#
#                                           properMotion  best18k  \
# baseline_v2.2_10yrs                                    0.186345
# carina_v2.2_10yrs                                      0.186525
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                0.185462
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                0.188589
# clouds_baseline_cloudso10_ns2_v2.2_10yrs               0.185754
# ...                                                         ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                       0.187078
# twi_neo_repeat4_z_np4_v2.2_10yrs                       0.186938
# twi_neo_repeat4_z_np5_v2.2_10yrs                       0.188335
# twi_neo_repeat4_z_np6_v2.2_10yrs                       0.187120
# twi_neo_repeat4_z_np7_v2.2_10yrs                       0.186485
#
#                                           tEff  Identity  tEff g Identity  \
# baseline_v2.2_10yrs                             0.612061         0.704731
# carina_v2.2_10yrs                               0.609865         0.691378
# clouds_baseline_cloudso0_ns2_v2.2_10yrs         0.599196         0.689902
# clouds_baseline_cloudso0_ns3_v2.2_10yrs         0.580548         0.667091
# clouds_baseline_cloudso10_ns2_v2.2_10yrs        0.576544         0.651698
# ...                                                  ...              ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                0.595738         0.710268
# twi_neo_repeat4_z_np4_v2.2_10yrs                0.599903         0.709934
# twi_neo_repeat4_z_np5_v2.2_10yrs                0.589203         0.716365
# twi_neo_repeat4_z_np6_v2.2_10yrs                0.590462         0.716792
# twi_neo_repeat4_z_np7_v2.2_10yrs                0.595563         0.703669
#
#                                           tEff i Identity  tEff r Identity  \
# baseline_v2.2_10yrs                              0.555172         0.724736
# carina_v2.2_10yrs                                0.550104         0.724830
# clouds_baseline_cloudso0_ns2_v2.2_10yrs          0.544015         0.708502
# clouds_baseline_cloudso0_ns3_v2.2_10yrs          0.528549         0.681236
# clouds_baseline_cloudso10_ns2_v2.2_10yrs         0.526969         0.685043
# ...                                                   ...              ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                 0.554559         0.736481
# twi_neo_repeat4_z_np4_v2.2_10yrs                 0.554186         0.730171
# twi_neo_repeat4_z_np5_v2.2_10yrs                 0.555083         0.737743
# twi_neo_repeat4_z_np6_v2.2_10yrs                 0.555606         0.732089
# twi_neo_repeat4_z_np7_v2.2_10yrs                 0.555366         0.734279
#
#                                           tEff u Identity  tEff y Identity  \
# baseline_v2.2_10yrs                              0.894119         0.507768
# carina_v2.2_10yrs                                0.892046         0.509668
# clouds_baseline_cloudso0_ns2_v2.2_10yrs          0.867210         0.500766
# clouds_baseline_cloudso0_ns3_v2.2_10yrs          0.855066         0.489035
# clouds_baseline_cloudso10_ns2_v2.2_10yrs         0.834013         0.482579
# ...                                                   ...              ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                 0.891281         0.504296
# twi_neo_repeat4_z_np4_v2.2_10yrs                 0.881268         0.513430
# twi_neo_repeat4_z_np5_v2.2_10yrs                 0.903045         0.508159
# twi_neo_repeat4_z_np6_v2.2_10yrs                 0.896043         0.507254
# twi_neo_repeat4_z_np7_v2.2_10yrs                 0.879965         0.507874
#
#                                           tEff z Identity  young_stars  Sum
# baseline_v2.2_10yrs                              0.521834      8.094331e+06
# carina_v2.2_10yrs                                0.521065      8.077371e+06
# clouds_baseline_cloudso0_ns2_v2.2_10yrs          0.510153      8.018135e+06
# clouds_baseline_cloudso0_ns3_v2.2_10yrs          0.492496      7.949799e+06
# clouds_baseline_cloudso10_ns2_v2.2_10yrs         0.488160      8.245219e+06
# ...                                                   ...               ...
# twi_neo_repeat4_z_np3_v2.2_10yrs                 0.455478      8.087704e+06
# twi_neo_repeat4_z_np4_v2.2_10yrs                 0.469172      8.118492e+06
# twi_neo_repeat4_z_np5_v2.2_10yrs                 0.428991      8.073400e+06
# twi_neo_repeat4_z_np6_v2.2_10yrs                 0.437201      8.113724e+06
# twi_neo_repeat4_z_np7_v2.2_10yrs                 0.457632      8.114824e+06
#
# [233 rows x 52017 columns]

# %%
plt.plot(data['properMotion  best18k'])

# %%
[col for col in data.columns if 'SNN' in col]
# Out:
# ['SNNSNMetric DD:COSMOS_nSN DD:COSMOS all bands Mean',
#  'SNNSNMetric DD:COSMOS_nSN DD:COSMOS all bands Median',
#  'SNNSNMetric DD:COSMOS_nSN DD:COSMOS all bands Sum',
#  'SNNSNMetric DD:COSMOS_zlim DD:COSMOS all bands Mean',
#  'SNNSNMetric DD:COSMOS_zlim DD:COSMOS all bands Median',
#  'SNNSNMetric DD:COSMOS_zlim DD:COSMOS all bands Sum',
#  'SNNSNMetric DD:ECDFS_nSN DD:ECDFS all bands Mean',
#  'SNNSNMetric DD:ECDFS_nSN DD:ECDFS all bands Median',
#  'SNNSNMetric DD:ECDFS_nSN DD:ECDFS all bands Sum',
#  'SNNSNMetric DD:ECDFS_zlim DD:ECDFS all bands Mean',
#  'SNNSNMetric DD:ECDFS_zlim DD:ECDFS all bands Median',
#  'SNNSNMetric DD:ECDFS_zlim DD:ECDFS all bands Sum',
#  'SNNSNMetric DD:EDFS_nSN DD:EDFS all bands Mean',
#  'SNNSNMetric DD:EDFS_nSN DD:EDFS all bands Median',
#  'SNNSNMetric DD:EDFS_nSN DD:EDFS all bands Sum',
#  'SNNSNMetric DD:EDFS_zlim DD:EDFS all bands Mean',
#  'SNNSNMetric DD:EDFS_zlim DD:EDFS all bands Median',
#  'SNNSNMetric DD:EDFS_zlim DD:EDFS all bands Sum',
#  'SNNSNMetric DD:ELAISS1_nSN DD:ELAISS1 all bands Mean',
#  'SNNSNMetric DD:ELAISS1_nSN DD:ELAISS1 all bands Median',
#  'SNNSNMetric DD:ELAISS1_nSN DD:ELAISS1 all bands Sum',
#  'SNNSNMetric DD:ELAISS1_zlim DD:ELAISS1 all bands Mean',
#  'SNNSNMetric DD:ELAISS1_zlim DD:ELAISS1 all bands Median',
#  'SNNSNMetric DD:ELAISS1_zlim DD:ELAISS1 all bands Sum',
#  'SNNSNMetric DD:WFD_nSN DD:WFD all bands Mean',
#  'SNNSNMetric DD:WFD_nSN DD:WFD all bands Median',
#  'SNNSNMetric DD:WFD_nSN DD:WFD all bands Sum',
#  'SNNSNMetric DD:WFD_zlim DD:WFD all bands Mean',
#  'SNNSNMetric DD:WFD_zlim DD:WFD all bands Median',
#  'SNNSNMetric DD:WFD_zlim DD:WFD all bands Sum',
#  'SNNSNMetric DD:XMM_LSS_nSN DD:XMM_LSS all bands Mean',
#  'SNNSNMetric DD:XMM_LSS_nSN DD:XMM_LSS all bands Median',
#  'SNNSNMetric DD:XMM_LSS_nSN DD:XMM_LSS all bands Sum',
#  'SNNSNMetric DD:XMM_LSS_zlim DD:XMM_LSS all bands Mean',
#  'SNNSNMetric DD:XMM_LSS_zlim DD:XMM_LSS all bands Median',
#  'SNNSNMetric DD:XMM_LSS_zlim DD:XMM_LSS all bands Sum',
#  'SNNSNMetric_nSN  Mean',
#  'SNNSNMetric_nSN  Median',
#  'SNNSNMetric_nSN  Total detected',
#  'SNNSNMetric_nSN  Total on sky',
#  'SNNSNMetric_zlim  Mean',
#  'SNNSNMetric_zlim  Median',
#  'SNNSNMetric_zlim  Total detected',
#  'SNNSNMetric_zlim  Total on sky']

# %%
fig, ax = plt.subplots()
good = np.where(data['SNNSNMetric DD:COSMOS_zlim DD:COSMOS all bands Sum'] > 0)
ax.plot(data['SNNSNMetric DD:COSMOS_zlim DD:COSMOS all bands Sum'].iloc[good])
_temp = ax.set_xticklabels(data.index,rotation=90)
# Out:
# /var/folders/05/z_zc9f654c5dlw06t4s_d68w0000gn/T/ipykernel_37174/2177160676.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _temp = ax.set_xticklabels(data.index,rotation=90)

# %%
good = np.where(data['SNNSNMetric DD:COSMOS_zlim DD:COSMOS all bands Sum'] > 25)[0]

data.index[good], data['SNNSNMetric DD:COSMOS_zlim DD:COSMOS all bands Sum'].values[good], data['SNNSNMetric DD:COSMOS_zlim DD:COSMOS all bands Median'].values[good]
# Out:
# (Index(['ddf_custom_v2.2_10yrs', 'ddf_deep_univ_0.2_v2.2_10yrs',
#         'ddf_quad_0.1_v2.2_10yrs', 'ddf_quad_0.2_v2.2_10yrs',
#         'ddf_quad_0.3_v2.2_10yrs'],
#        dtype='object'),
#  array([43.2435155, 36.7091285, 28.1994405, 32.036338 , 37.5679125]),
#  array([0.59471  , 0.578117 , 0.503562 , 0.5163235, 0.541755 ]))

# %%
fig, ax = plt.subplots()
ax.plot(data['SNNSNMetric_nSN  Total detected'])
_temp = ax.set_xticklabels(data.index,rotation=90)
# Out:
# /var/folders/05/z_zc9f654c5dlw06t4s_d68w0000gn/T/ipykernel_37174/90403398.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _temp = ax.set_xticklabels(data.index,rotation=90)

# %%
plt.plot(data['SNNSNMetric_nSN  Total detected'])

# %%
plt.plot(data['SNNSNMetric_zlim  Median'])
