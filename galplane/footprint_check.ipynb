# %%
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline 
import galplane_footprint as gf
import numpy as np

# %%
agg_level = 1.5
nside=32
gp_map = gf.read_galplane_footprint(agg_level)
footprints_hp_array, labels = gf.return_maps_galplane_sky(nside, gp_map)

# %%
for key in footprints_hp_array.dtype.names:
    hp.mollview(footprints_hp_array[key], title=key)

# %%
agg_level = 2.0
nside=32
gp_map = gf.read_galplane_footprint(agg_level)
footprints_hp_array, labels = gf.return_maps_galplane_sky(nside, gp_map)

# %%
for key in footprints_hp_array.dtype.names:
    hp.mollview(footprints_hp_array[key], title=key)
