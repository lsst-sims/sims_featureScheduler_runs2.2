# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import pandas as pd

# %%
data = pd.read_hdf('summary.h5')

# %%
data
# Out:
# metric                                    Mean SNSLMetric DD:ELAISS1 all bands HealpixSubsetSlicer  \
# run_name
# baseline_v2.2_10yrs                                                                0.000010
# clouds_baseline_cloudso0_ns2_v2.2_10yrs                                            0.000010
# clouds_baseline_cloudso0_ns3_v2.2_10yrs                                            0.000010
# clouds_baseline_cloudso10_ns2_v2.2_10yrs                                           0.000009
# clouds_baseline_cloudso10_ns3_v2.2_10yrs                                           0.000010
# clouds_baseline_cloudso11_ns2_v2.2_10yrs                                           0.000010
# clouds_baseline_cloudso11_ns3_v2.2_10yrs                                           0.000010
# clouds_baseline_cloudso1_ns2_v2.2_10yrs                                            0.000009
# clouds_baseline_cloudso1_ns3_v2.2_10yrs                                            0.000010
# ...

# %%
data.columns
# Out:
# Index(['Mean SNSLMetric DD:ELAISS1 all bands HealpixSubsetSlicer',
#        'Median SNSLMetric DD:ELAISS1 all bands HealpixSubsetSlicer',
#        'Sum SNSLMetric DD:ELAISS1 all bands HealpixSubsetSlicer',
#        'Mean AGN_TimeLag_100_days DD:ELAISS1 all bands HealpixSubsetSlicer',
#        'Median AGN_TimeLag_100_days DD:ELAISS1 all bands HealpixSubsetSlicer',
#        'Rms AGN_TimeLag_100_days DD:ELAISS1 all bands HealpixSubsetSlicer',
#        'Mean AGN_TimeLag_5_days DD:ELAISS1 all bands HealpixSubsetSlicer',
#        'Median AGN_TimeLag_5_days DD:ELAISS1 all bands HealpixSubsetSlicer',
#        'Rms AGN_TimeLag_5_days DD:ELAISS1 all bands HealpixSubsetSlicer',
#        'Median DD:ELAISS1 NVisits all bands HealpixSubsetSlicer',
#        ...
#        'Effective Area (deg) ExgalM5_with_cuts i band non-DD year 9 HealpixSlicer',
#        '3x2ptFoM ExgalM5_with_cuts i band non-DD year 9 HealpixSlicer',
#        '3x2ptFoM_simple ExgalM5_with_cuts i band non-DD year 9 HealpixSlicer',
# ...

# %%
print([col for col in data.columns if 'Number' in col and 'Expo' in col])
# Out:
# ['Number of Exposures', 'Number of Exposures g', 'Number of Exposures i', 'Number of Exposures z', 'Number of Exposures y', 'Number of Exposures u', 'Number of Exposures r']

# %%
data['Number of Exposures']
# Out:
# run_name
# baseline_v2.2_10yrs                         2075598.0
# clouds_baseline_cloudso0_ns2_v2.2_10yrs     2086426.0
# clouds_baseline_cloudso0_ns3_v2.2_10yrs     2090178.0
# clouds_baseline_cloudso10_ns2_v2.2_10yrs    2194374.0
# clouds_baseline_cloudso10_ns3_v2.2_10yrs    2197123.0
# clouds_baseline_cloudso11_ns2_v2.2_10yrs    2196447.0
# clouds_baseline_cloudso11_ns3_v2.2_10yrs    2199486.0
# clouds_baseline_cloudso1_ns2_v2.2_10yrs     2079791.0
# clouds_baseline_cloudso1_ns3_v2.2_10yrs     2082217.0
# clouds_baseline_cloudso20_ns2_v2.2_10yrs    2197453.0
# clouds_baseline_cloudso20_ns3_v2.2_10yrs    2199562.0
# clouds_baseline_cloudso21_ns2_v2.2_10yrs    2197918.0
# clouds_baseline_cloudso21_ns3_v2.2_10yrs    2200492.0
# clouds_baseline_cloudso30_ns2_v2.2_10yrs    2144093.0
# clouds_baseline_cloudso30_ns3_v2.2_10yrs    2146566.0
# clouds_baseline_cloudso31_ns2_v2.2_10yrs    2162022.0
# clouds_baseline_cloudso31_ns3_v2.2_10yrs    2164822.0
# ...
