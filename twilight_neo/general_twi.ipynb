# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import rubin_sim.maf as maf

# %%
bundleList = []
plotDict = {}
colmap = maf.batches.ColMapDict("opsimV4")
nside=64
spatial_slicer = maf.slicers.HealpixSlicer
sqls = ['note="twilight_neo"', 'note!="twilight_neo"',
        'note="twilight_neo" and night=10', 'note="twilight_neo" and night=11']
slicer = spatial_slicer(
        nside=nside,
        latCol=colmap["alt"],
        lonCol=colmap["az"],
        latLonDeg=colmap["raDecDeg"],
        useCache=False,
    )
metric = maf.metrics.CountMetric(
    colmap["mjd"], metricName="Nvisits as function of Alt/Az"
)
plotFuncs = [maf.plots.LambertSkyMap()]

plotDict = {"norm": "log"}
for sql in sqls:
    bundle = maf.metricBundles.MetricBundle(
        metric,
        slicer,
        sql,
        plotFuncs=plotFuncs,
        plotDict=plotDict,
        runName='twilight_neo_nightpattern1v2.0'
    )
    bundleList.append(bundle)
# Out:
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes

# %%
bd = maf.metricBundles.makeBundlesDictFromList(bundleList)
g = maf.MetricBundleGroup(bd, 'twi_neo_repeat3_iz_np1_v2.2_10yrs.db', 'temp')

# %%
g.runAll()
g.plotAll(closefigs=False)
# Out:
# Querying table None with constraint note="twilight_neo" and night=11 for columns ['rotSkyPos', 'observationStartMJD', 'altitude', 'azimuth']
# Found 139 visits
# Running:  ['twilight_neo_nightpattern1v2_0_Nvisits_as_function_of_Alt_Az_notetwilight_neo_and_night11_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying table None with constraint note="twilight_neo" for columns ['rotSkyPos', 'observationStartMJD', 'altitude', 'azimuth']
# Found 338215 visits
# Running:  ['twilight_neo_nightpattern1v2_0_Nvisits_as_function_of_Alt_Az_notetwilight_neo_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying table None with constraint note!="twilight_neo" for columns ['rotSkyPos', 'observationStartMJD', 'altitude', 'azimuth']
# Found 1898368 visits
# Running:  ['twilight_neo_nightpattern1v2_0_Nvisits_as_function_of_Alt_Az_note!twilight_neo_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying table None with constraint note="twilight_neo" and night=10 for columns ['rotSkyPos', 'observationStartMJD', 'altitude', 'azimuth']
# Found 144 visits
# Running:  ['twilight_neo_nightpattern1v2_0_Nvisits_as_function_of_Alt_Az_notetwilight_neo_and_night10_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "note="twilight_neo" and night=11" constraint now.
# Plotting complete.
# Plotting figures with "note="twilight_neo"" constraint now.
# Plotting complete.
# Plotting figures with "note!="twilight_neo"" constraint now.
# Plotting complete.
# Plotting figures with "note="twilight_neo" and night=10" constraint now.
# Plotting complete.
