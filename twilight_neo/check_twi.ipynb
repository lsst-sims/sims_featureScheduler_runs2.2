# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import rubin_sim.maf as maf

# %%
bundleList = []
plotDict = {}
colmap = maf.batches.ColMapDict("opsimV4")
nside=64
spatial_slicer = maf.slicers.HealpixSlicer
sqls = ['note="twilight_neo"', 'note!="twilight_neo"', 'note="twilight_neo" and night=4']
slicer = spatial_slicer(
        nside=nside,
        latCol=colmap["alt"],
        lonCol=colmap["az"],
        latLonDeg=colmap["raDecDeg"],
        useCache=False,
    )
metric = maf.metrics.CountMetric(
    colmap["mjd"], metricName="Nvisits as function of Alt/Az"
)
plotFuncs = [maf.plots.LambertSkyMap()]

plotDict = {"norm": "log"}
for sql in sqls:
    bundle = maf.metricBundles.MetricBundle(
        metric,
        slicer,
        sql,
        plotFuncs=plotFuncs,
        plotDict=plotDict,
        runName='twi_neo_repeat3_riz_np1_v2.2'
    )
    bundleList.append(bundle)
# Out:
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes

# %%
bd = maf.metricBundles.makeBundlesDictFromList(bundleList)
g = maf.MetricBundleGroup(bd, 'twi_neo_repeat3_riz_np1_v2.2_0yrs.db', 'temp')

# %%
g.runAll()
g.plotAll(closefigs=False)
# Out:
# Querying table None with constraint note!="twilight_neo" for columns ['rotSkyPos', 'altitude', 'azimuth', 'observationStartMJD']
# Found 3352 visits
# Running:  ['twilight_neo_nightpattern1v2_1_Nvisits_as_function_of_Alt_Az_note!twilight_neo_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying table None with constraint note="twilight_neo" and night=4 for columns ['rotSkyPos', 'altitude', 'azimuth', 'observationStartMJD']
# Found 138 visits
# Running:  ['twilight_neo_nightpattern1v2_1_Nvisits_as_function_of_Alt_Az_notetwilight_neo_and_night4_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying table None with constraint note="twilight_neo" for columns ['rotSkyPos', 'altitude', 'azimuth', 'observationStartMJD']
# Found 606 visits
# Running:  ['twilight_neo_nightpattern1v2_1_Nvisits_as_function_of_Alt_Az_notetwilight_neo_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "note!="twilight_neo"" constraint now.
# Plotting complete.
# Plotting figures with "note="twilight_neo" and night=4" constraint now.
# Plotting complete.
# Plotting figures with "note="twilight_neo"" constraint now.
# Plotting complete.
